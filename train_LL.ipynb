# %%
import gymnasium as gym
from stable_baselines3 import DQN

env = gym.make("LunarLander-v3")

model = DQN("MlpPolicy", env, verbose=1, device="cpu")
model.learn(total_timesteps=100000)

model.save("Trained_LL")
